# %%
#Seaborn is a library which is works for data visualization.It's build on the based on the  matplotlib.
#If we works on seabornlib first we have to import matplotlib

# %% [markdown]
# The Seaborn library provides several built-in datasets that can be easily accessed for data visualization and analysis.
# Here is a list of the names of the built-in datasets available in Seaborn:
#       anagrams,
# anscombe,
# attention,
# brain_networks,
# car_crashes,
# diamonds,
# dots,
# exercise,
# flights,
# fmri,
# gammas,
# geyser,
# iris,
# mpg,
# penguins,
# planets,
# tips,
# titanic,

# %%
#seaborn Line plot
import seaborn as sns
from matplotlib import pyplot as plt

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
# Create a line plot using Seaborn
sns.lineplot(x='timepoint', y='signal', data=fmri)
plt.title('Seaborn Line plot')
plt.show()

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# Load the 'fmri' dataset
fmri = sns.load_dataset('fmri')

# Create a line plot using Seaborn
sns.lineplot(x='timepoint', y='signal', data=fmri)

# Set plot labels and title
plt.xlabel('Timepoint')
plt.ylabel('Signal')
plt.title('FMRI Signal Over Time')

# Display the plot
plt.show()

# %%
fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
#fmri = sns.load_dataset('fmri')

sns.lineplot(x = "timepoint",y = "signal",data = fmri)

plt.show()

# %%
diamonds =  sns.load_dataset('diamonds')
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.lineplot(x = 'cut',y = 'depth',data = diamonds)
plt.show()

# %%
sns.lineplot(x = 'depth',y = 'table',data = diamonds)
plt.show()

# %%
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
diamonds.shape
# Out:
# (53940, 10)

# %%
planets = sns.load_dataset("planets")
planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
planets.tail()
# Out:
#        method  number  orbital_period  mass  distance  year
# 1030  Transit       1        3.941507   NaN     172.0  2006
# 1031  Transit       1        2.615864   NaN     148.0  2007
# 1032  Transit       1        3.191524   NaN     174.0  2007
# 1033  Transit       1        4.125083   NaN     293.0  2008
# 1034  Transit       1        4.187757   NaN     260.0  2008

# %%
planets.shape
# Out:
# (1035, 6)

# %%
planets.describe()
# Out:
#             number  orbital_period        mass     distance         year
# count  1035.000000      992.000000  513.000000   808.000000  1035.000000
# mean      1.785507     2002.917596    2.638161   264.069282  2009.070531
# std       1.240976    26014.728304    3.818617   733.116493     3.972567
# min       1.000000        0.090706    0.003600     1.350000  1989.000000
# 25%       1.000000        5.442540    0.229000    32.560000  2007.000000
# 50%       1.000000       39.979500    1.260000    55.250000  2010.000000
# 75%       2.000000      526.005000    3.040000   178.500000  2012.000000
# max       7.000000   730000.000000   25.000000  8500.000000  2014.000000

# %%
exercise = sns.load_dataset('exercise')
exercise.head()
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
sns.lineplot(x = 'pulse',y = 'time',data=exercise)
plt.show()

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.tail()
# Out:
#      year month  passengers
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432

# %%
sns.lineplot(x = 'month', y = 'passengers',data = flights)
plt.show()

# %%
flights.shape
# Out:
# (144, 3)

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x = 'timepoint', y = 'signal', data= fmri,hue = 'event')
plt.title('Seaborn Lineplot')
plt.show()

# %%
sns.lineplot(x = 'timepoint', y = 'signal', data= fmri,hue = 'event',style= 'event')
plt.title('Seaborn Lineplot')
plt.show()

# %%
#Adding markers
sns.lineplot(x = 'timepoint', y = 'signal',markers = True,hue = 'event',style= 'event',data= fmri)
plt.title('Seaborn Lineplot')
plt.show()

# %%
#Bar plot
import pandas as pd
salary = pd.read_csv(r'C:\Users\Bain\.vscode\PythonB\JPNB\salaries.csv')

# %%
salary
# Out:
#        work_year experience_level employment_type                  job_title  \
# 0           2024               SE              FT                AI Engineer
# 1           2024               SE              FT  Machine Learning Engineer
# 2           2024               SE              FT  Machine Learning Engineer
# 3           2024               SE              FT  Machine Learning Engineer
# 4           2024               SE              FT  Machine Learning Engineer
# ...          ...              ...             ...                        ...
# 13967       2020               SE              FT             Data Scientist
# 13968       2021               MI              FT   Principal Data Scientist
# 13969       2020               EN              FT             Data Scientist
# 13970       2020               EN              CT      Business Data Analyst
# 13971       2021               SE              FT       Data Science Manager
#
# ...

# %%
salary.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2024               SE              FT                AI Engineer
# 1       2024               SE              FT  Machine Learning Engineer
# 2       2024               SE              FT  Machine Learning Engineer
# 3       2024               SE              FT  Machine Learning Engineer
# 4       2024               SE              FT  Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   90000             USD          90000                 AE             0
# 1  180500             USD         180500                 US             0
# 2   96200             USD          96200                 US             0
# 3  235000             USD         235000                 AU             0
# 4  175000             USD         175000                 AU             0
#
#   company_location company_size
# 0               AE            L
# ...

# %%
salary.tail()
# Out:
#        work_year experience_level employment_type                 job_title  \
# 13967       2020               SE              FT            Data Scientist
# 13968       2021               MI              FT  Principal Data Scientist
# 13969       2020               EN              FT            Data Scientist
# 13970       2020               EN              CT     Business Data Analyst
# 13971       2021               SE              FT      Data Science Manager
#
#         salary salary_currency  salary_in_usd employee_residence  \
# 13967   412000             USD         412000                 US
# 13968   151000             USD         151000                 US
# 13969   105000             USD         105000                 US
# 13970   100000             USD         100000                 US
# 13971  7000000             INR          94665                 IN
#
#        remote_ratio company_location company_size
# 13967           100               US            L
# ...

# %%
salary.shape
# Out:
# (13972, 11)

# %%
sns.barplot(x = 'experience_level',y = 'employment_type' ,data= salary)
plt.show()

# %%
#Pair Plot
dx = sns.load_dataset('iris')
sns.pairplot(dx,hue = 'species')
plt.show()
